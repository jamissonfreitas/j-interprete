# %%
from PIL import Image
import pytesseract

# %%
img = Image.open('/home/james/Documentos/projects/j-interprete/jinterprete/ocr_test.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=369x366 at 0x7FA63CABB1D0>

# %%
text = pytesseract.image_to_string(img)

# %%
text
# Out:
# 'Mobility is the key to youmompanys dynamic\nbusiness environment. Many businesses\nrealize that mobility enables business\nmomentum by creating greater efﬁcrency and\nproductivtty that drives growth. ASUS realizes\ncustomers have different ideas about what\nmobility can do for them, With the ASUSPRO\nBusiness Notebook family you can match\nyour mobility needs to a product that delivers\nthe right combination of reliability, quality and\nunique ease of use features in a wide range of\nform rectors. Whether on the road, or at your\ndesk, ASUSPRO Series notebooks maximize\nthe beneﬁts of mobile computing.'

# %%
text.split('\n')
# Out:
# ['Mobility is the key to youmompanys dynamic',
#  'business environment. Many businesses',
#  'realize that mobility enables business',
#  'momentum by creating greater efﬁcrency and',
#  'productivtty that drives growth. ASUS realizes',
#  'customers have different ideas about what',
#  'mobility can do for them, With the ASUSPRO',
#  'Business Notebook family you can match',
#  'your mobility needs to a product that delivers',
#  'the right combination of reliability, quality and',
#  'unique ease of use features in a wide range of',
#  'form rectors. Whether on the road, or at your',
#  'desk, ASUSPRO Series notebooks maximize',
#  'the beneﬁts of mobile computing.']
